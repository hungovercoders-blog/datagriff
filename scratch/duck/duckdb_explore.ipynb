# %%
import duckdb
import pandas as pd

# import plotly_express as px

# %load_ext magic_duckdb

# %%
# %%dql
# FORCE INSTALL delta FROM core_nightly;
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %%dql
# UPDATE EXTENSIONS
# Out:
#   extension_name    repository        update_result previous_version  \
# 0          azure          core  NO_UPDATE_AVAILABLE          b0ffe7a
# 1         httpfs          core  NO_UPDATE_AVAILABLE           v1.1.1
# 2          delta  core_nightly  NO_UPDATE_AVAILABLE           v0.2.1
#
#   current_version
# 0         b0ffe7a
# 1          v1.1.1
# 2          v0.2.1

# %%
# %%dql
# CREATE OR REPLACE SECRET cheese (TYPE AZURE, PROVIDER CREDENTIAL_CHAIN, SCOPE 'abfss://lrndlkcheese12345hngc.dfs.core.windows.net/')
# Out:
#    Success
# 0     True

# %%
# %%dql
# SET azure_transport_option_type = 'curl'; --important for when running in linux!
# SET azure_http_stats = false;
# SET azure_read_transfer_concurrency = 5;
# SET azure_read_transfer_chunk_size = 1_048_576;
# SET azure_read_buffer_size = 1_048_576;
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %%dql
# DESCRIBE
# FROM 'abfss://lrndlkcheese12345hngc.dfs.core.windows.net/lake/csv/cheeses.csv';
# Out:
#         column_name column_type null   key default extra
# 0            cheese     VARCHAR  YES  None    None  None
# 1               url     VARCHAR  YES  None    None  None
# 2              milk     VARCHAR  YES  None    None  None
# 3           country     VARCHAR  YES  None    None  None
# 4            region     VARCHAR  YES  None    None  None
# 5            family     VARCHAR  YES  None    None  None
# 6              type     VARCHAR  YES  None    None  None
# 7       fat_content     VARCHAR  YES  None    None  None
# 8   calcium_content     VARCHAR  YES  None    None  None
# 9           texture     VARCHAR  YES  None    None  None
# 10             rind     VARCHAR  YES  None    None  None
# 11            color     VARCHAR  YES  None    None  None
# 12           flavor     VARCHAR  YES  None    None  None
# 13            aroma     VARCHAR  YES  None    None  None
# 14       vegetarian     VARCHAR  YES  None    None  None
# 15            vegan     VARCHAR  YES  None    None  None
# 16         synonyms     VARCHAR  YES  None    None  None
# 17    alt_spellings     VARCHAR  YES  None    None  None
# 18        producers     VARCHAR  YES  None    None  None

# %%
# %%dql
# SELECT *
# FROM 'abfss://lrndlkcheese12345hngc.dfs.core.windows.net/lake/csv/cheeses.csv'
# LIMIT 5;
# Out:
#               cheese                                        url   milk  \
# 0         Aarewasser         https://www.cheese.com/aarewasser/    cow
# 1   Abbaye de Belloc   https://www.cheese.com/abbaye-de-belloc/  sheep
# 2   Abbaye de Belval   https://www.cheese.com/abbaye-de-belval/    cow
# 3  Abbaye de Citeaux  https://www.cheese.com/abbaye-de-citeaux/    cow
# 4    Abbaye de Tamié              https://www.cheese.com/tamie/    cow
#
#        country       region family                        type fat_content  \
# 0  Switzerland           NA     NA                   semi-soft          NA
# 1       France  Pays Basque     NA          semi-hard, artisan          NA
# 2       France           NA     NA                   semi-hard      40-46%
# 3       France     Burgundy     NA  semi-soft, artisan, brined          NA
# 4       France       Savoie     NA               soft, artisan          NA
#
#   calcium_content                texture     rind   color  \
# 0              NA                buttery   washed  yellow
# 1              NA    creamy, dense, firm  natural  yellow
# 2              NA                elastic   washed   ivory
# 3              NA  creamy, dense, smooth   washed   white
# 4              NA   creamy, open, smooth   washed   white
#
#                   flavor              aroma vegetarian  vegan  \
# 0                  sweet            buttery      FALSE  FALSE
# 1          burnt caramel           lanoline       TRUE  FALSE
# 2                     NA           aromatic      FALSE  FALSE
# 3  acidic, milky, smooth  barnyardy, earthy      FALSE  FALSE
# 4          fruity, nutty  perfumed, pungent      FALSE  FALSE
#
#                       synonyms                              alt_spellings  \
# 0                           NA                                         NA
# 1  Abbaye Notre-Dame de Belloc                                         NA
# 2                           NA                                         NA
# 3                           NA                                         NA
# 4                           NA  Tamié, Trappiste de Tamie, Abbey of Tamie
#
#   producers
# 0      Jumi
# 1        NA
# 2        NA
# 3        NA
# 4        NA

# %%
# %%dql
# CREATE OR REPLACE SECRET delta (
#     TYPE AZURE,
#     PROVIDER CREDENTIAL_CHAIN,
#     CHAIN 'cli;default',
#     ACCOUNT_NAME 'lrndlkcheese12345hngc'
# );
# Out:
#    Success
# 0     True

# %%
# %%dql
# SELECT *
# FROM delta_scan('abfss://lake/csv/cheeses/')
# LIMIT 5;
# Out:
# ---------------------------------------------------------------------------
# IOException                               Traceback (most recent call last)
# File /workspace/.pyenv_mirror/user/current/lib/python3.12/site-packages/magic_duckdb/duckdb_mode.py:135, in DuckDbMode.execute(self, query_string, connection, export_function, explain_function, params, export_kwargs)
#     134         execute = True
# --> 135     r = execute_db(
#     136         query=query_string, con=connection, params=params, execute=execute
#     137     )
#     138 except Exception as e:
#
# File /workspace/.pyenv_mirror/user/current/lib/python3.12/site-packages/magic_duckdb/duckdb_mode.py:17, in execute_db(query, con, execute, params)
#      16 if execute or params is not None:
# ---> 17     return con.execute(query, parameters=params)
#      18 else:
#
# IOException: IO Error: Hit DeltaKernel FFI error (from: While trying to read from delta table: 'abfss://lake/csv/cheeses/'): Hit error: 15 (MissingVersionError) with message (No table version found.)
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 get_ipython().run_cell_magic('dql', '', "SELECT *\nFROM delta_scan('abfss://lake/csv/cheeses/')\nLIMIT 5;\n")
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /workspace/.pyenv_mirror/user/current/lib/python3.12/site-packages/magic_duckdb/magic.py:239, in DuckDbMagic.execute(self, line, cell, local_ns)
#     236 if args.tables:
#     237     return thisconnection.get_table_names(query)
# --> 239 o = dbwrapper.execute(
#     240     query_string=query,
#     241     connection=thisconnection,
#     242     export_function=args.type[0]
#     243     if args.type
#     244     else self.default_export_function,
#     245     explain_function=explain_function,
#     246     params=queryparams,
#     247     export_kwargs=export_kwargs
#     248 )
#     249 if args.output:
#     250     user_ns[args.output[0]] = o
#
# File /workspace/.pyenv_mirror/user/current/lib/python3.12/site-packages/magic_duckdb/duckdb_mode.py:139, in DuckDbMode.execute(self, query_string, connection, export_function, explain_function, params, export_kwargs)
#     135     r = execute_db(
#     136         query=query_string, con=connection, params=params, execute=execute
#     137     )
#     138 except Exception as e:
# --> 139     raise ValueError(f"Error executing {query_string} in DuckDB") from e
#     141 if r is None or ("relation" == export_function):
#     142     return r
#
# ValueError: Error executing SELECT *
# FROM delta_scan('abfss://lake/csv/cheeses/')
# LIMIT 5; in DuckDB

# %%
# %%time
# %%dql -t show
SELECT * FROM 'https://github.com/cwida/duckdb-data/releases/download/v1.0/taxi_2019_04.parquet' LIMIT 5;
# Out:
# ┌───────────┬─────────────────────┬─────────────────────┬─────────────────┬───────────────┬──────────────┬────────────────────┬────────────────────┬─────────────────────┬──────────────┬─────────────┬───────┬─────────┬────────────┬──────────────┬───────────────────────┬──────────────┬──────────────────────┐
# │ vendor_id │      pickup_at      │     dropoff_at      │ passenger_count │ trip_distance │ rate_code_id │ store_and_fwd_flag │ pickup_location_id │ dropoff_location_id │ payment_type │ fare_amount │ extra │ mta_tax │ tip_amount │ tolls_amount │ improvement_surcharge │ total_amount │ congestion_surcharge │
# │  varchar  │      timestamp      │      timestamp      │      int8       │     float     │   varchar    │      varchar       │       int32        │        int32        │   varchar    │    float    │ float │  float  │   float    │    float     │         float         │    float     │        float         │
# ├───────────┼─────────────────────┼─────────────────────┼─────────────────┼───────────────┼──────────────┼────────────────────┼────────────────────┼─────────────────────┼──────────────┼─────────────┼───────┼─────────┼────────────┼──────────────┼───────────────────────┼──────────────┼──────────────────────┤
# │ 1         │ 2019-04-01 00:04:09 │ 2019-04-01 00:06:35 │               1 │           0.5 │ 1            │ N                  │                239 │                 239 │ 1            │         4.0 │   3.0 │     0.5 │        1.0 │          0.0 │                   0.3 │          8.8 │                  2.5 │
# │ 1         │ 2019-04-01 00:22:45 │ 2019-04-01 00:25:43 │               1 │           0.7 │ 1            │ N                  │                230 │                 100 │ 2            │         4.5 │   3.0 │     0.5 │        0.0 │          0.0 │                   0.3 │          8.3 │                  2.5 │
# │ 1         │ 2019-04-01 00:39:48 │ 2019-04-01 01:19:39 │               1 │          10.9 │ 1            │ N                  │                 68 │                 127 │ 1            │        36.0 │   3.0 │     0.5 │       7.95 │          0.0 │                   0.3 │        47.75 │                  2.5 │
# │ 1         │ 2019-04-01 00:35:32 │ 2019-04-01 00:37:11 │               1 │           0.2 │ 1            │ N                  │                 68 │                  68 │ 2            │         3.5 │   3.0 │     0.5 │        0.0 │          0.0 │                   0.3 │          7.3 │                  2.5 │
# │ 1         │ 2019-04-01 00:44:05 │ 2019-04-01 00:57:58 │               1 │           4.8 │ 1            │ N                  │                 50 │                  42 │ 1            │        15.5 │   3.0 │     0.5 │       3.85 │          0.0 │                   0.3 │        23.15 │                  2.5 │
# └───────────┴─────────────────────┴─────────────────────┴─────────────────┴───────────────┴──────────────┴────────────────────┴────────────────────┴─────────────────────┴──────────────┴─────────────┴───────┴─────────┴────────────┴──────────────┴───────────────────────┴──────────────┴──────────────────────┘
#
# CPU times: user 768 ms, sys: 290 ms, total: 1.06 s
# Wall time: 3.2 s

# %%
# %%time
# %%dql -t show
SELECT * FROM 'https://github.com/cwida/duckdb-data/releases/download/v1.0/taxi_2019_04.parquet' LIMIT 5;

# %%
# %%dql -t df
# SELECT
#        format('{:,}', CAST(ROUND((sum(total_compressed_size) / (1024))) AS INT)) as compressed_KB,
#        format('{:,}', CAST(ROUND((sum(total_uncompressed_size) / (1024))) AS INT)) as uncompressed_KB,
#        format('{:,}', CAST(ROUND((sum(total_compressed_size) / (1024 * 1024))) AS INT)) as compressed_MB,
#        format('{:,}', CAST(ROUND((sum(total_uncompressed_size) / (1024 * 1024))) AS INT)) as uncompressed_MB,
#        sum(total_compressed_size) / (1024 * 1024 * 1024) as compressed_GB,
#        sum(total_uncompressed_size) / (1024 * 1024 * 1024) as uncompressed_GB
# FROM parquet_metadata('https://github.com/cwida/duckdb-data/releases/download/v1.0/taxi_2019_04.parquet')
# Out:
# UsageError: Cell magic `%%dql` not found.
